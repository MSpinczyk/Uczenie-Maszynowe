# %% [markdown]
# #Clustering
#
# ##K-means clustering - example I
#
# ### Michał Spinczyk

# %%
from sklearn.datasets import make_blobs 
 
help(make_blobs)
# Out:
# Help on function make_blobs in module sklearn.datasets._samples_generator:
#
# make_blobs(n_samples=100, n_features=2, *, centers=None, cluster_std=1.0, center_box=(-10.0, 10.0), shuffle=True, random_state=None, return_centers=False)
#     Generate isotropic Gaussian blobs for clustering.
#
#     Read more in the :ref:`User Guide <sample_generators>`.
#
#     Parameters
#     ----------
#     n_samples : int or array-like, default=100
#         If int, it is the total number of points equally divided among
#         clusters.
#         If array-like, each element of the sequence indicates
#         the number of samples per cluster.
#
#         .. versionchanged:: v0.20
#             one can now pass an array-like to the ``n_samples`` parameter
#
#     n_features : int, default=2
#         The number of features for each sample.
#
#     centers : int or ndarray of shape (n_centers, n_features), default=None
#         The number of centers to generate, or the fixed center locations.
# ...

# %%
X, y = make_blobs(n_samples = 120, n_features = 2,centers = 4, cluster_std=0.40)
print(X,y)
print(X.shape, y.shape)
# Out:
# [[ 9.26228013e+00 -4.85446838e+00]
#  [ 9.37049517e+00 -4.53976160e+00]
#  [ 7.86095671e+00 -2.37843058e+00]
#  [-6.47156591e+00 -1.50619971e-01]
#  [ 8.18102268e+00 -2.26778988e+00]
#  [-7.14795065e+00 -1.55617478e-01]
#  [ 8.15367524e+00 -2.52612523e+00]
#  [ 8.34982020e+00 -2.33893335e+00]
#  [ 4.65159904e+00 -3.83505210e-01]
#  [ 7.93472254e+00 -3.04157512e+00]
#  [ 1.00461415e+01 -5.45919495e+00]
#  [ 1.00254228e+01 -4.90771286e+00]
#  [-7.05692745e+00  1.05398597e+00]
#  [ 8.82961908e+00 -1.55905022e+00]
#  [ 9.84761355e+00 -5.26607541e+00]
#  [ 1.01973847e+01 -5.00264208e+00]
#  [-6.41216665e+00  6.28842389e-03]
#  [-6.62827452e+00  3.84109230e-01]
#  [ 9.64277621e+00 -4.67966750e+00]
#  [ 9.44300587e+00 -1.99662656e+00]
#  [ 8.28164597e+00 -2.87737685e+00]
#  [-6.89002837e+00 -1.49823740e-01]
#  [ 8.82681452e+00 -2.58072377e+00]
#  [ 8.23311522e+00 -1.92388498e+00]
#  [ 9.83701892e+00 -4.88339853e+00]
#  [ 3.77705419e+00  4.26726446e-01]
#  [ 1.03387701e+01 -4.76375766e+00]
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

kmeans = KMeans(n_clusters=4, random_state=0).fit(X)
# print(kmeans.labels_)
predicted = kmeans.predict(X)
print(predicted)

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1],label = predicted, c = predicted)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# df = pd.DataFrame(dict(feature_1=X[:,0], feature_2=X[:,1], classification = continent))

# fig, ax = plt.subplots()

# colors = {'North America':'red', 'Europe':'green', 'Asia':'blue', 'Australia':'yellow'}


# ax.scatter(df['population'], df['Area'], c=df['continent'].map(colors))

# plt.show()
# Out:
# [2 2 3 1 3 1 3 3 0 3 2 2 1 3 2 2 1 1 2 3 3 1 3 3 2 0 2 0 0 1 1 0 0 0 0 1 3
#  1 3 1 3 2 1 0 0 2 3 2 2 1 1 1 3 0 2 1 1 3 3 2 2 3 1 0 0 2 3 0 0 2 3 1 1 0
#  1 0 2 0 2 2 3 3 1 3 0 2 0 3 1 1 3 1 0 2 3 2 0 0 3 1 0 2 0 0 2 2 2 3 3 1 3
#  1 2 2 0 1 0 0 1 0]

# %%
print("Inertia:",kmeans.inertia_)
# Out:
# Inertia: 38.93453693389103

# %% [markdown]
# ## K-means clustering - example II

# %%
X, y = make_blobs(n_samples = 120, n_features = 2,centers = 6, cluster_std=0.80)

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

kmeans = KMeans(n_clusters=6, random_state=0).fit(X)
# print(kmeans.labels_)
predicted = kmeans.predict(X)
# print(predicted)

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1],label = predicted, c = predicted)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
print("Inertia:",kmeans.inertia_)
# Out:
# Inertia: 126.00662006449073

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
# print(kmeans.labels_)
predicted = kmeans.predict(X)
# print(predicted)

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1],label = predicted, c = predicted)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
print("Inertia:",kmeans.inertia_)
# Out:
# Inertia: 6503.632160559859

# %% [markdown]
# ## K-means ++

# %%
kmeans = KMeans(n_clusters=6, random_state=0,init='k-means++').fit(X)
# print(kmeans.labels_)
predicted = kmeans.predict(X)
# print(predicted)

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1],label = predicted, c = predicted)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
print("Inertia:",kmeans.inertia_)
# Out:
# Inertia: 126.00662006449073

# %% [markdown]
# ## Elbow method

# %%
n = 21
k = np.arange(1,n,1)

inertions = []
for i in range(1,n):
  kmeans = KMeans(n_clusters=i, random_state=0,init='k-means++').fit(X)
  # print(kmeans.labels_)
  predicted = kmeans.predict(X)
  # print(predicted)
  inertions.append(kmeans.inertia_)

plt.figure(figsize=(15,10))
plt.plot(k,inertions)
plt.xlabel('Inertia')
plt.ylabel('k')
plt.show()

# %%
from sklearn.datasets import make_moons
import seaborn as sns
import pandas as pd
 
x, y = make_moons(1000, noise=.05, random_state=0)
X_moon = pd.DataFrame(x, columns = ['f1','f2'])
#TODO: Kmeans
kmeans = KMeans(2, random_state=0).fit(X_moon)
y_km = kmeans.predict(X_moon)
centers = kmeans.cluster_centers_
                                               
#Plot
X_moon['k_means'] = y_km
sns.lmplot(data=X_moon, x='f1', y='f2', fit_reg=False, hue = 'k_means', palette = ['#eb6c6a', '#6aeb6c']).set(title='Algorytm k-srednich')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.5)
plt.show()

# %% [markdown]
# ## Clustering II - hierarchical methods

# %% [markdown]
# ### Dendrograms

# %%
X, y_true = make_blobs(n_samples=300, centers=5,
                       cluster_std=0.8, random_state=0)

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1],label = y_true, c = y_true)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
# print(kmeans.labels_)
predicted = kmeans.predict(X)
# print(predicted)

plt.figure(figsize=(15,10))
plt.scatter(X[:,0],X[:,1],label = predicted, c = predicted)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

Z = linkage(X)
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)

# %%
X, y_true = make_blobs(n_samples=50, centers=5,
                       cluster_std=0.8, random_state=0)

Z = linkage(X)
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)

# %% [markdown]
# ### Agglomerative clustering

# %%
df = pd.read_csv('shopping_data.csv')
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data = df.iloc[:, 3:5].values
data
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
plt.figure(figsize = (13,8))
plt.scatter(data[:,0],data[:,1])
plt.show()

# %%
Z = linkage(data,method='ward')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)

# %%
from sklearn.cluster import AgglomerativeClustering

fig, axs = plt.subplots(1, 4,figsize = (25,5))

cluster = AgglomerativeClustering(n_clusters=5,  linkage='single')
cluster.fit_predict(data)

axs[0].scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')
axs[0].set_title('Single Linkage')
axs[0].set_xlabel('Annual earnings')
axs[0].set_ylabel('Spending')

cluster = AgglomerativeClustering(n_clusters=5,  linkage='complete')
cluster.fit_predict(data)

axs[1].scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')
axs[1].set_title('Complete Linkage')
axs[1].set_xlabel('Annual earnings')
axs[1].set_ylabel('Spending')

cluster = AgglomerativeClustering(n_clusters=5,  linkage='average')
cluster.fit_predict(data)

axs[2].scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')
axs[2].set_title('Average Linkage')
axs[2].set_xlabel('Annual earnings')
axs[2].set_ylabel('Spending')

cluster = AgglomerativeClustering(n_clusters=5,  linkage='ward')
cluster.fit_predict(data)

axs[3].scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')
axs[3].set_title('Ward Linkage')
axs[3].set_xlabel('Annual earnings')
axs[3].set_ylabel('Spending')

fig.show()

# %% [markdown]
# ### Selecting the number of clusters with silhouette analysis on KMeans clustering

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

X, y = make_blobs(n_samples=500,
                  n_features=2,
                  centers=4,
                  cluster_std=1,
                  center_box=(-10.0, 10.0),
                  shuffle=True,
                  random_state=1)

plt.figure(figsize = (13,8))
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    labels = clusterer.fit_predict(X)
    silhouette_avg = silhouette_score(X, labels)
    print("Dla n_klastrów =", n_clusters,"Średnia wartość silhouette_score wynosi :",silhouette_avg,)

    # Obliczanie silhouette dla każdej próbki
    sample_silhouette_values = silhouette_samples(X, labels)

    y_lower = 10
    for i in range(n_clusters):
        # Zebranie wyników silhouette dla próbek należących do klastra oraz posortowanie ich i stworzenie wykresu

        ith_cluster_silhouette_values = sample_silhouette_values[labels == i]
        ith_cluster_silhouette_values.sort()
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),0,ith_cluster_silhouette_values,facecolor=color,edgecolor=color,alpha=0.7,)
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("Silhouette coefficient values")
    ax1.set_ylabel("Cluster label")
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    colors = cm.nipy_spectral(labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k")
    centers = clusterer.cluster_centers_
    ax2.scatter(centers[:, 0],centers[:, 1],marker="o",c="white",alpha=1,s=200,edgecolor="k")

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature 1")
    ax2.set_ylabel("Feature 2")

    plt.suptitle("Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"% n_clusters,fontsize=14,fontweight="bold",)

plt.show()
# Out:
# Dla n_klastrów = 2 Średnia wartość silhouette_score wynosi : 0.7049787496083262
# Dla n_klastrów = 3 Średnia wartość silhouette_score wynosi : 0.5882004012129721
# Dla n_klastrów = 4 Średnia wartość silhouette_score wynosi : 0.6505186632729437
# Dla n_klastrów = 5 Średnia wartość silhouette_score wynosi : 0.56376469026194
# Dla n_klastrów = 6 Średnia wartość silhouette_score wynosi : 0.4504666294372765

# %% [markdown]
# ### DBSCAN algorithm

# %%
from sklearn import  datasets
# ============
# Generate datasets.
# ============
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None
 
# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)
 
# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# %%
from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler

plt.figure(figsize=(13, 13))

plot_num = 1

default_base = {
    "quantile": 0.3,
    "eps": 0.3,
    "damping": 0.9,
    "preference": -200,
    "n_neighbors": 10,
    "n_clusters": 3,
    "min_samples": 20,
    "xi": 0.05,
    "min_cluster_size": 0.1,
}

datasets = [(noisy_circles,{
            "damping": 0.77,
            "preference": -240,
            "quantile": 0.2,
            "n_clusters": 2,
            "min_samples": 20,
            "xi": 0.25,},),
    (noisy_moons, {"damping": 0.75, "preference": -220, "n_clusters": 2}),
    (
        varied,
        {
            "eps": 0.18,
            "n_neighbors": 2,
            "min_samples": 5,
            "xi": 0.035,
            "min_cluster_size": 0.2,
        },
    ),
    (
        aniso,
        {
            "eps": 0.15,
            "n_neighbors": 2,
            "min_samples": 20,
            "xi": 0.1,
            "min_cluster_size": 0.2,
        },
    ),
    (blobs, {}),
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    params = default_base.copy()
    params.update(algo_params)
    X, y = dataset
    X = StandardScaler().fit_transform(X)
    bandwidth = cluster.estimate_bandwidth(X, quantile=params["quantile"])
    connectivity = kneighbors_graph(X, n_neighbors=params["n_neighbors"], include_self=False)
    connectivity = 0.5 * (connectivity + connectivity.T)

    kmeans = cluster.KMeans(n_clusters=params["n_clusters"])
    ward = cluster.AgglomerativeClustering(n_clusters=params["n_clusters"], linkage="ward", connectivity=connectivity)
    dbscan = cluster.DBSCAN(eps=params["eps"])
    average_linkage = cluster.AgglomerativeClustering(linkage="average",affinity="cityblock",n_clusters=params["n_clusters"],connectivity=connectivity)

    clustering_algorithms = (("KMeans", kmeans),("Ward", ward),("Agglomerative\nClustering", average_linkage),("DBSCAN", dbscan))
    
    for name, algorithm in clustering_algorithms:
        algorithm.fit(X)

        if hasattr(algorithm, "labels_"):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        plt.scatter(X[:, 0], X[:, 1], s=10, c=y_pred)

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plot_num += 1

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py:281: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   X, connectivity, affinity="euclidean"
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py:551: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   X, connectivity, affinity=affinity
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py:281: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   X, connectivity, affinity="euclidean"
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_agglomerative.py:551: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
# ...

# %% [markdown]
# ## Wnioski
#
# Na labolatorium udało mi się wykonać wszytskir zadania, dwa ostatnie zostały wykonane z pomocą dokumentacji sklearn oraz przykładów tamże zamieszczonych. Pierwsze zadania nie stanowiły większego problemu, udało się zastosować algorytmy KMeans oraz KMeans ++ do klasteryzacji, dodatkowo użyłem elbow method. Udało się również stworzyć parę dendogramów. Analizując wykresy uzyskane w Agglomerative clustering możmy zauważyć iżnajlepiej sobie poradziły dwie metody: Complete Linkage oraz Ward Linkage. Przy zastosowaniu silhouette analysis oraz KMeans możemy zauważyć iż najlepiej model działa dla liczby klastrów = 4, zgodnie z utworzeniem danych. W tym zadaniu wspomogłem się dokumentacją oraz przykładem, gdyż moje wykresy nie wyglądały na tyle dobrze. W ostatnim zadaniu porównałem różne algorytmy do klasteryzacji - czyli KMeans, Agglomerative Clustering, Ward oraz DBSCAN. Analizując otrymane wykresy możemy dojść do wniosku iż w zależności z jakimi danymi mamy doczynienia taki algorytm sobie lepiej radzi. Tutaj również wspomogłem siędokumentacją oraz przykładem.
